# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Create Synthetic datapoints

# %%
from sklearn.datasets import make_classification
X,y=make_classification(n_samples=1000,n_features=2,n_classes=2,n_clusters_per_class=2,n_redundant=0)

# %%
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Slopes
svc.coef_
# Out:
# array([[0.03005541, 1.35488156]])

# %%
y_pred = svc.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
                 'C' : [0.1, 1, 10, 100, 1000],
                 'gamma' : [1, 0.1, 0.01, 0.001, 0.0001],
                 'kernel' : ['linear']
             }

# %%
grid = GridSearchCV(SVC(), param_grid=parameters, refit=True, cv = 5, verbose = 3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.900 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.0s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.820 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.893 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.893 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.847 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.820 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.820 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.893 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.893 total time=   0.1s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.847 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.820 total time=   0.1s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.820 total time=   0.1s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.893 total time=   0.1s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.893 total time=   0.1s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.847 total time=   0.1s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.820 total time=   0.1s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.820 total time=   0.1s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.893 total time=   0.1s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.893 total time=   0.1s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.847 total time=   0.1s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.820 total time=   0.1s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.1s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.1s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.1s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.1s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.820 total time=   1.0s
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.893 total time=   0.6s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.893 total time=   0.7s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.847 total time=   0.8s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.820 total time=   0.6s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.820 total time=   1.0s
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.893 total time=   0.6s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.893 total time=   0.7s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.847 total time=   0.8s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.820 total time=   0.6s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.820 total time=   1.0s
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.893 total time=   0.6s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.893 total time=   0.7s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.847 total time=   0.8s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.820 total time=   0.6s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.820 total time=   1.0s
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.893 total time=   0.6s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.893 total time=   0.7s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.847 total time=   0.8s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.820 total time=   0.6s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.820 total time=   1.0s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.6s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.7s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.8s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.820 total time=   0.6s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'linear'}

# %%
y_pred4=grid.predict(X_test)
print(classification_report(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       121
#            1       0.87      0.89      0.88       129
#
#     accuracy                           0.88       250
#    macro avg       0.88      0.88      0.88       250
# weighted avg       0.88      0.88      0.88       250
#
# [[104  17]
#  [ 14 115]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       2 print(classification_report(y_test,y_pred4))
#       3 print(confusion_matrix(y_test,y_pred4))
# ----> 4 print(accuracy_score(y_test,y_pred))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:220, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     154 """Accuracy classification score.
#     155
#     156 In multilabel classification, this function computes subset accuracy:
#    (...)
#     216 0.5
#     217 """
#     219 # Compute accuracy for each possible representation
# --> 220 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     221 check_consistent_length(y_true, y_pred, sample_weight)
#     222 if y_type.startswith("multilabel"):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [250, 750]
